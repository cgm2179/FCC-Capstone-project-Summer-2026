# %% [markdown]
# <a href="https://colab.research.google.com/github/cgm2179/indoor-walk-test/blob/main/Physics%20Engine/3D%20Map%20Physics/SIM%20V2/Indoor/Multiband_resumable_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⭐ Multiband Resumable — **v2 (NEW)** · 80-transmitter high-diversity retrain
#
# **Use this notebook, not the v1.** The first run (v1: 20 Tx × 150 boxes) validated end-to-end but held-out accuracy was mediocre (coherence ~0.54) — too few *distinct* scenes (the 150 boxes/Tx are correlated crops of one solve). This **v2** trains on **80 transmitters × 40 boxes** = the same ~22k corpus but **4× the distinct propagation scenes**, which is the main lever for held-out accuracy.
#
# - Outputs are **config-tagged** (`shards_tx80_b40/`, `unet3d_tx80_b40.npz`, …) so this regenerates fresh and your v1 run stays intact for comparison.
# - Data-gen is ~4× longer (560 solves vs 140) but fully resumable — lower `N_TX` to 40–60 if credits are tight.
# - After training, run **Phase D** to confirm coherence climbs toward >0.85.
#
# ---

# %% [markdown]
# # SIM V2 3D — Resumable high-detail 7-band training (Phase B + C · A100)
#
# Generate conformal **18-channel** training data for **all 7 bands** at **λ/10** full-detail resolution
# and train ONE pure-JAX 3-D U-Net (**base=48, ~13 M params**) on the lot, with a **Helmholtz-residual
# physics loss**. Built to **survive Colab timeouts**: everything (shards, checkpoints, weights) lives on
# **Google Drive**, every band is **marked done**, training **checkpoints every 5 epochs**. On a restart
# just **Runtime → Run all** — Phase B skips finished bands, Phase C resumes from the last checkpoint.
#
# - **Bands**: `LTE_B71_617 · LTE_B13_751 · LTE_B2_1960 · NR_n41_2506 · NR_n77_3700 · WiFi_2G4 · WiFi_5G`
# - **Detail**: per-Tx **mesh bake @ λ/10** with adaptive super (~5 mm effective-medium floor) — full CAD
#   detail at the solve resolution. The 329 MB OBJ **ships in the repo gzipped (76 MB)** and is auto-
#   decompressed in §0b — no upload needed. (Or set `MESH_BAKE=False` for the coarser frozen-geometry path.)
# - **GPU**: pick an **A100** (Runtime → Change runtime type). **CuPy** runs the voxelizer's closing +
#   distance-transform on-device and **JAX/XLA** runs the FDTD (`simulate_jax`) — the whole pipeline is GPU.
# - **Input channels (18)**: 6 material one-hot + Tx + freq + log-dist + εr + σ + SDF + 3 normals + the
#   **antenna current map |Jx|,|Jy|,|Jz|**. **Output**: complex scalar field (Re, Im).

# %%
import os
os.environ.setdefault("XLA_PYTHON_CLIENT_PREALLOCATE", "false")  # let CuPy (voxelizer) share the GPU with JAX
# === Environment bootstrap: Colab or local ===
import sys
from pathlib import Path
try:
    import google.colab            # noqa: F401
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    BRANCH = "sim-v2-multiband-resumable"   # branch carrying the high-detail pipeline + frac.npy
    REPO = Path("/content/indoor-walk-test")
    if not REPO.exists():
        # !git clone --depth 1 -b {BRANCH} https://github.com/cgm2179/indoor-walk-test.git "{REPO}"
else:
    here = Path.cwd()
    REPO = next((p for p in [here, *here.parents] if (p / "Physics Engine").is_dir()),
                Path("/Users/cameronmickle/Documents/Indoor_Walk_Test_7-7"))
SIMV2 = REPO / "Physics Engine" / "3D Map Physics" / "SIM V2"
sys.path.insert(0, str(SIMV2))
print("IN_COLAB:", IN_COLAB, "| REPO:", REPO)
# Out:
# Cloning into '/content/indoor-walk-test'...
# remote: Enumerating objects: 1529, done.
# remote: Counting objects: 100% (1529/1529), done.
# remote: Compressing objects: 100% (1071/1071), done.
# remote: Total 1529 (delta 457), reused 1401 (delta 437), pack-reused 0 (from 0)
# Receiving objects: 100% (1529/1529), 238.79 MiB | 18.88 MiB/s, done.
# Resolving deltas: 100% (457/457), done.
# Updating files: 100% (1527/1527), done.
# IN_COLAB: True | REPO: /content/indoor-walk-test

# %% [markdown]
# ## 0a · Persistence — mount Google Drive
# **This is what makes it resumable.** All shards + checkpoints + weights live in one Drive folder that
# outlives the runtime; a fresh session re-mounts it and the pipeline picks up where it stopped.

# %%
if IN_COLAB:
    from google.colab import drive
    drive.mount("/content/drive")
    PERSIST = Path("/content/drive/MyDrive/simv2_multiband")   # <- your Drive; survives timeouts
else:
    PERSIST = SIMV2 / "multiband_run"
PERSIST.mkdir(parents=True, exist_ok=True)
SHARDS  = PERSIST / "shards"        # per-band 18-ch shards + done-markers
CONF    = PERSIST / "conformal"     # per-band composed grids (frozen-geometry fallback only)
CKPT    = PERSIST / "unet3d_ckpt.pkl"   # (params + optax state + epoch) — the resume file
WEIGHTS = PERSIST / "unet3d_jax.npz"    # final exported weights
print("persist ->", PERSIST)
for p in sorted(PERSIST.rglob("*"))[:20]:
    print("  ", p.relative_to(PERSIST))
# Out:
# Mounted at /content/drive
# persist -> /content/drive/MyDrive/simv2_multiband
#    phaseD_617.png
#    shards
#    shards/LTE_B13_751
#    shards/LTE_B13_751/dataset_meta.json
#    shards/LTE_B13_751/shard_000.npz
#    shards/LTE_B13_751/shard_001.npz
#    shards/LTE_B13_751/shard_002.npz
#    shards/LTE_B13_751/shard_003.npz
#    shards/LTE_B13_751/shard_004.npz
#    shards/LTE_B13_751/shard_005.npz
#    shards/LTE_B13_751/shard_006.npz
#    shards/LTE_B13_751/shard_007.npz
#    shards/LTE_B13_751/shard_008.npz
#    shards/LTE_B13_751/shard_009.npz
#    shards/LTE_B13_751/shard_010.npz
#    shards/LTE_B13_751/shard_011.npz
#    shards/LTE_B13_751/shard_012.npz
#    shards/LTE_B13_751/shard_013.npz
#    shards/LTE_B13_751/shard_014.npz
#    shards/LTE_B13_751/shard_015.npz

# %% [markdown]
# ## 0b · Full-detail geometry — decompress the committed OBJ + enable CuPy
# `MESH_BAKE=True` voxelizes the real CAD per transmitter at λ/10, so the OBJ must be on the node. It
# **ships in the repo gzipped** (`SIM V2/data/floor7.obj.gz`, 76 MB) and this cell **auto-decompresses**
# it once — no upload. (A Drive copy at `MyDrive/simv2_multiband/…obj` is used as a fallback if present.)
# **CuPy** (pre-installed on Colab CUDA) runs the voxelizer's closing + distance-transform on the GPU;
# the JAX/XLA FDTD (`simulate_jax`) is already on the GPU.

# %%
import voxelize_conformal as VC, gzip, shutil
OBJ_GZ    = SIMV2 / "data" / "floor7.obj.gz"                            # committed (gzipped, 76 MB)
OBJ_LOCAL = Path("/content/floor7.obj") if IN_COLAB else (SIMV2 / "data" / "floor7.obj")
OBJ_DRIVE = PERSIST / "3ff8432c-980b-41b6-9045-c09dbe1d74cc copy.obj"   # optional Drive fallback
if OBJ_GZ.exists() and not OBJ_LOCAL.exists():
    print("decompressing committed OBJ (once) …")
    with gzip.open(OBJ_GZ, "rb") as f, open(OBJ_LOCAL, "wb") as g:
        shutil.copyfileobj(f, g)
if OBJ_LOCAL.exists():
    VC.OBJ = str(OBJ_LOCAL)
elif OBJ_DRIVE.exists():
    VC.OBJ = str(OBJ_DRIVE)
else:
    print("⚠ no OBJ found — set MESH_BAKE=False for the frozen-geometry path")
print("OBJ ->", VC.OBJ)
# CuPy backend for the voxelizer (closing + distance transform on-device); JAX already runs the FDTD on GPU
try:
    import cupy; VC.USE_GPU = VC._HAS_CUPY
except Exception:
    VC.USE_GPU = False
print("voxelizer backend:", "CuPy/GPU" if VC.USE_GPU else "NumPy/CPU")
# Out:
# decompressing committed OBJ (once) …
# OBJ -> /content/floor7.obj
# voxelizer backend: CuPy/GPU

# %%
import numpy as np, glob, time, json
import jax
import bootstrap  # noqa: F401  (SIM V2 path shim)
import fw_dataset3d as D
import unet3d_train_jax as T
print("JAX backend:", jax.default_backend(), "| devices:", jax.devices())
# Out:
# JAX backend: gpu | devices: [CudaDevice(id=0)]

# %% [markdown]
# ## 1 · Configuration

# %%
BANDS = ["LTE_B71_617", "LTE_B13_751", "LTE_B2_1960", "NR_n41_2506",
         "NR_n77_3700", "WiFi_2G4", "WiFi_5G"]
N_TX       = 80      # transmitters per band
BOXES_PER  = 40     # 24³ boxes cropped per Tx (stratified over x/y/z) -> 7*80*40 = 22,400 (4x more distinct Tx scenes) boxes
EPOCHS     = 120
BASE       = 48      # U-Net base width (~13 M params)
BS         = 32      # batch size (A100)
SUPER      = "auto"  # adaptive geometry supersampling (~5 mm floor): 8 @ low bands, 2-3 @ high
MESH_BAKE  = True    # per-Tx mesh bake @ λ/10 from the OBJ (full detail). False = frozen-geometry (coarser)
ANTENNA    = True    # 18-ch input with |Jx|,|Jy|,|Jz|; ~50% of Tx are directional (panel patterns)
PHYS_WT    = 0.05    # Helmholtz-residual loss weight (0 = pure MSE)
CKPT_EVERY = 2       # checkpoint to Drive every N epochs (a kill loses ≤N epochs; set 1 for max safety)

GEOM = REPO / "Physics Engine" / "3D Map Physics" / "SIM V1 3D" / "conformal" / "LTE_B71_617"  # frac.npy (fallback)
for b in BANDS:
    print(f"  {b:14s} region={D.BAND_PLAN[b][0]}m  npw=λ/{D.BAND_PLAN[b][1]:.0f}")

# Tag output folders by config so changing N_TX/BOXES_PER regenerates FRESH
# (done-markers would otherwise [skip] the old shards and keep the previous run).
tag = f"tx{N_TX}_b{BOXES_PER}"
SHARDS  = PERSIST / f"shards_{tag}"
CKPT    = PERSIST / f"unet3d_ckpt_{tag}.pkl"
WEIGHTS = PERSIST / f"unet3d_{tag}.npz"
print("outputs ->", SHARDS.name, "|", CKPT.name, "|", WEIGHTS.name)
# Out:
#   LTE_B71_617    region=6.0m  npw=λ/10
#   LTE_B13_751    region=6.0m  npw=λ/10
#   LTE_B2_1960    region=4.0m  npw=λ/10
#   NR_n41_2506    region=3.5m  npw=λ/10
#   NR_n77_3700    region=2.5m  npw=λ/10
#   WiFi_2G4       region=3.5m  npw=λ/10
#   WiFi_5G        region=2.0m  npw=λ/10
# outputs -> shards_tx80_b40 | unet3d_ckpt_tx80_b40.pkl | unet3d_tx80_b40.npz

# %% [markdown]
# ## 2 · Corpus + rough time (measure epoch 1 for the real number)

# %%
dev = jax.default_backend()
boxes = len(BANDS) * N_TX * BOXES_PER
steps = (boxes + BS - 1) // BS * EPOCHS
print(f"runtime={dev}   corpus={boxes:,} boxes   {steps:,} train-steps (base={BASE}, bs={BS})")
_sv = len(BANDS) * N_TX
print(f"  Phase B ({_sv} solves = 7 bands x {N_TX} Tx): ~{_sv/60:.0f}-{_sv*2.5/60:.0f} h on A100 (data-gen time scales with N_TX)")
if dev == "cpu":
    print("  Phase C: base-48 on 63k boxes is INFEASIBLE on CPU — switch to an A100 GPU runtime.")
else:
    print(f"  Phase C ({EPOCHS} ep): rough ~10–40 h on A100 — the first epoch prints its wall-time,")
    print( "           multiply by EPOCHS for the real estimate. Checkpointed → spread across sessions.")
    print(f"  Shrink knobs if needed: EPOCHS↓, BOXES_PER↓, or N_TX↓.")
# Out:
# runtime=gpu   corpus=22,400 boxes   84,000 train-steps (base=48, bs=32)
#   Phase B (560 solves = 7 bands x 80 Tx): ~9-23 h on A100 (data-gen time scales with N_TX)
#   Phase C (120 ep): rough ~10–40 h on A100 — the first epoch prints its wall-time,
#            multiply by EPOCHS for the real estimate. Checkpointed → spread across sessions.
#   Shrink knobs if needed: EPOCHS↓, BOXES_PER↓, or N_TX↓.

# %% [markdown]
# ## 3 · Phase B — generate all 7 bands (resumable, marked)
#
# Per band: solve `N_TX` transmitters (mesh bake @ λ/10 + adaptive super; ~50% directional), crop 300
# stratified 18-channel boxes, write shards to Drive, drop a `dataset_meta.json` **done-marker**.
# Re-running **skips** finished bands — a timeout only ever costs the band in flight.

# %%
t0 = time.time()
D.generate_bands(BANDS, out_root=SHARDS, conformal_root=CONF, geom_dir=str(GEOM),
                 n_tx=N_TX, boxes_per=BOXES_PER, seed=1, mesh_bake=MESH_BAKE, super=SUPER,
                 antenna=ANTENNA, directional_frac=0.5)
done = [b for b in BANDS if (SHARDS / b / "dataset_meta.json").exists()]
print(f"\nPhase B: {len(done)}/{len(BANDS)} bands done in {time.time()-t0:.0f}s  -> {done}")
# Out:
# [mesh] LTE_B71_617: per-Tx mesh bake @ λ/10 + adaptive super (full detail)
# [gen ] LTE_B71_617: n_tx=80 boxes=40 region=6.0m npw=λ/10
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 000 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 001 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 002 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 003 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 004 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 005 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 006 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 007 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 008 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 009 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 010 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 011 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 012 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 013 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 014 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 015 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 016 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 017 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 018 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 019 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 020 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 021 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 022 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 023 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 024 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 025 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 026 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 027 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 028 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 029 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 030 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 031 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 032 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 033 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 034 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 035 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 036 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 037 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 038 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 039 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 040 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 041 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 042 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 043 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 044 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 045 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 046 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 047 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 048 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 049 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 050 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 051 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 052 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 053 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 054 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 055 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 056 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 057 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 058 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 059 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 060 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 061 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 062 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 063 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 064 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 065 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 066 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 067 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 068 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 069 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 070 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 071 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 072 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 073 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 074 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 075 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 076 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 077 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 078 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 079 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
# wrote/verified 80 conformal shards -> /content/drive/MyDrive/simv2_multiband/shards_tx80_b40/LTE_B71_617
# [done] LTE_B71_617
# [mesh] LTE_B13_751: per-Tx mesh bake @ λ/10 + adaptive super (full detail)
# [gen ] LTE_B13_751: n_tx=80 boxes=40 region=6.0m npw=λ/10
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 000 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 001 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 002 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 003 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 004 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 005 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 006 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 007 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 008 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 009 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 010 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 011 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 012 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 013 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 014 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 015 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 016 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 017 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 018 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 019 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 020 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 021 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 022 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 023 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 024 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 025 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 026 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 027 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 028 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 029 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 030 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 031 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 032 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 033 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 034 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 035 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 036 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 037 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 038 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 039 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 040 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 041 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 042 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 043 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 044 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 045 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 046 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 047 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 048 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 049 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 050 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 051 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 052 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 053 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 054 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 055 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 056 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 057 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 058 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 059 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 060 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 061 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 062 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 063 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 064 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 065 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 066 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 067 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 068 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 069 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 070 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 071 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 072 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 073 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 074 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 075 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 076 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 077 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 078 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 079 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
# wrote/verified 80 conformal shards -> /content/drive/MyDrive/simv2_multiband/shards_tx80_b40/LTE_B13_751
# [done] LTE_B13_751
# [mesh] LTE_B2_1960: per-Tx mesh bake @ λ/10 + adaptive super (full detail)
# [gen ] LTE_B2_1960: n_tx=80 boxes=40 region=4.0m npw=λ/10
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 000 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 001 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 002 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 003 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 004 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 005 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 006 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 007 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 008 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 009 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 010 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 011 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 012 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 013 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 014 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 015 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 016 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 017 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 018 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 019 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 020 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 021 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 022 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 023 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 024 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 025 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 026 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 027 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 028 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 029 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 030 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 031 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 032 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 033 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 034 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 035 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 036 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 037 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 038 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 039 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 040 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 041 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 042 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 043 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 044 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 045 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 046 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 047 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 048 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 049 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 050 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 051 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 052 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 053 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 054 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 055 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 056 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 057 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 058 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 059 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 060 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 061 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 062 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 063 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 064 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 065 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 066 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 067 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 068 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 069 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 070 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 071 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 072 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 073 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 074 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 075 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 076 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 077 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 078 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 079 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
# wrote/verified 80 conformal shards -> /content/drive/MyDrive/simv2_multiband/shards_tx80_b40/LTE_B2_1960
# [done] LTE_B2_1960
# [mesh] NR_n41_2506: per-Tx mesh bake @ λ/10 + adaptive super (full detail)
# [gen ] NR_n41_2506: n_tx=80 boxes=40 region=3.5m npw=λ/10
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 000 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 001 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 002 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 003 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 004 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 005 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 006 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 007 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 008 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 009 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 010 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 011 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 012 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 013 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 014 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 015 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 016 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 017 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 018 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 019 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 020 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 021 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 022 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 023 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 024 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 025 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 026 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 027 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 028 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 029 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 030 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 031 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 032 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 033 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 034 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 035 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 036 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 037 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 038 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 039 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 040 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 041 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 042 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 043 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 044 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 045 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 046 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 047 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 048 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 049 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 050 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 051 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 052 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 053 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 054 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 055 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 056 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 057 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 058 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 059 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 060 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 061 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 062 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 063 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 064 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 065 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 066 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 067 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 068 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 069 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 070 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 071 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 072 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 073 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 074 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 075 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 076 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 077 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 078 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 079 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
# wrote/verified 80 conformal shards -> /content/drive/MyDrive/simv2_multiband/shards_tx80_b40/NR_n41_2506
# [done] NR_n41_2506
# [mesh] NR_n77_3700: per-Tx mesh bake @ λ/10 + adaptive super (full detail)
# [gen ] NR_n77_3700: n_tx=80 boxes=40 region=2.5m npw=λ/10
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 000 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 001 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 002 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 003 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 004 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 005 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 006 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 007 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 008 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 009 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 010 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 011 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 012 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 013 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 014 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 015 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 016 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 017 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 018 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 019 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 020 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 021 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 022 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 023 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 024 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 025 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 026 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 027 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 028 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 029 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 030 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 031 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 032 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 033 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 034 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 035 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 036 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 037 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 038 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
# ...
#   shard 041 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 042 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 043 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 044 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 045 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 046 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 047 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 048 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 049 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 050 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 051 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 052 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 053 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 054 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 055 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 056 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 057 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 058 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 059 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 060 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 061 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 062 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 063 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 064 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 065 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 066 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 067 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 068 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 069 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 070 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 071 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 072 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 073 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 074 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 075 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 076 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 077 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 078 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 079 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
# wrote/verified 80 conformal shards -> /content/drive/MyDrive/simv2_multiband/shards_tx80_b40/WiFi_2G4
# [done] WiFi_2G4
# [mesh] WiFi_5G: per-Tx mesh bake @ λ/10 + adaptive super (full detail)
# [gen ] WiFi_5G: n_tx=80 boxes=40 region=2.0m npw=λ/10
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 000 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 001 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 002 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 003 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 004 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 005 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 006 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 007 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 008 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 009 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 010 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 011 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 012 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 013 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 014 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 015 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 016 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 017 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 018 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 019 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 020 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 021 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 022 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 023 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 024 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 025 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 026 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 027 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 028 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 029 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 030 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 031 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 032 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 033 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 034 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 035 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 036 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 037 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 038 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 039 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 040 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 041 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 042 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 043 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 044 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 045 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 046 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 047 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 048 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 049 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 050 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 051 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 052 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 053 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 054 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 055 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 056 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 057 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 058 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 059 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 060 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 061 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 062 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 063 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 064 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 065 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 066 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 067 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 068 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 069 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 070 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 071 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 072 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 073 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 074 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 075 boxes=40 x(18, 24, 24, 24) [directional 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 076 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 077 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 078 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   shard 079 boxes=40 x(18, 24, 24, 24) [iso 18-ch]
# wrote/verified 80 conformal shards -> /content/drive/MyDrive/simv2_multiband/shards_tx80_b40/WiFi_5G
# [done] WiFi_5G
#
# Phase B: 7/7 bands done in 56701s  -> ['LTE_B71_617', 'LTE_B13_751', 'LTE_B2_1960', 'NR_n41_2506', 'NR_n77_3700', 'WiFi_2G4', 'WiFi_5G']

# %% [markdown]
# ## 4 · Phase C — train the U-Net on all bands (resumable)
#
# `train_resumable` loads every band's shards and every 5 epochs saves `(params + optax state + epoch)`
# to `CKPT` on Drive; a fresh session reloads it and continues from the saved epoch. Loss = MSE +
# `PHYS_WT`·Helmholtz-residual (∇²E+k²εr·E, isotropic samples only). Raise `EPOCHS` and re-run to train
# further — it resumes, never restarts.

# %%
T.train_resumable(str(SHARDS), total_epochs=EPOCHS, base=BASE, bs=BS,
                  ckpt=str(CKPT), ckpt_every=CKPT_EVERY, out=str(WEIGHTS), phys_weight=PHYS_WT)
print("weights ->", WEIGHTS)
# Out:
# data x(22400, 18, 24, 24, 24) y(22400, 2, 24, 24, 24)  cin=18 cout=2  base=48  device=gpu  boxes=22400  phys_weight=0.05  iso_frac=0.45
# [fresh ] training 0/120
#   ep  0/120  mse=0.04475  phys=0.01008  70.0s/ep  ·  119 epochs left  ·  ETA 2.31 h (≈Sun 09:18)
#   ep  1/120  mse=0.03977  phys=0.01614  49.1s/ep  ·  118 epochs left  ·  ETA 1.61 h (≈Sun 08:37)
#     [ckpt] epoch 2 -> unet3d_ckpt_tx80_b40.pkl
#   ep  2/120  mse=0.03830  phys=0.01831  49.2s/ep  ·  117 epochs left  ·  ETA 1.60 h (≈Sun 08:37)
#   ep  3/120  mse=0.03766  phys=0.01996  49.2s/ep  ·  116 epochs left  ·  ETA 1.58 h (≈Sun 08:37)
#     [ckpt] epoch 4 -> unet3d_ckpt_tx80_b40.pkl
#   ep  4/120  mse=0.03735  phys=0.02062  49.2s/ep  ·  115 epochs left  ·  ETA 1.57 h (≈Sun 08:37)
#   ep  5/120  mse=0.03709  phys=0.02104  49.2s/ep  ·  114 epochs left  ·  ETA 1.56 h (≈Sun 08:37)
#     [ckpt] epoch 6 -> unet3d_ckpt_tx80_b40.pkl
#   ep  6/120  mse=0.03680  phys=0.02243  49.2s/ep  ·  113 epochs left  ·  ETA 1.54 h (≈Sun 08:37)
#   ep  7/120  mse=0.03623  phys=0.02411  49.2s/ep  ·  112 epochs left  ·  ETA 1.53 h (≈Sun 08:37)
#     [ckpt] epoch 8 -> unet3d_ckpt_tx80_b40.pkl
#   ep  8/120  mse=0.03580  phys=0.02475  49.2s/ep  ·  111 epochs left  ·  ETA 1.52 h (≈Sun 08:37)
#   ep  9/120  mse=0.03579  phys=0.02555  49.1s/ep  ·  110 epochs left  ·  ETA 1.50 h (≈Sun 08:37)
#     [ckpt] epoch 10 -> unet3d_ckpt_tx80_b40.pkl
#   ep 10/120  mse=0.03555  phys=0.02538  49.2s/ep  ·  109 epochs left  ·  ETA 89.3 min (≈Sun 08:37)
#   ep 11/120  mse=0.03524  phys=0.02608  49.1s/ep  ·  108 epochs left  ·  ETA 88.5 min (≈Sun 08:37)
#     [ckpt] epoch 12 -> unet3d_ckpt_tx80_b40.pkl
#   ep 12/120  mse=0.03481  phys=0.02669  49.1s/ep  ·  107 epochs left  ·  ETA 87.6 min (≈Sun 08:37)
#   ep 13/120  mse=0.03427  phys=0.02727  49.1s/ep  ·  106 epochs left  ·  ETA 86.8 min (≈Sun 08:37)
#     [ckpt] epoch 14 -> unet3d_ckpt_tx80_b40.pkl
#   ep 14/120  mse=0.03396  phys=0.02769  49.1s/ep  ·  105 epochs left  ·  ETA 86.0 min (≈Sun 08:37)
#   ep 15/120  mse=0.03396  phys=0.02869  49.2s/ep  ·  104 epochs left  ·  ETA 85.2 min (≈Sun 08:37)
#     [ckpt] epoch 16 -> unet3d_ckpt_tx80_b40.pkl
#   ep 16/120  mse=0.03307  phys=0.02806  49.4s/ep  ·  103 epochs left  ·  ETA 84.4 min (≈Sun 08:37)
#   ep 17/120  mse=0.03328  phys=0.02776  49.0s/ep  ·  102 epochs left  ·  ETA 83.6 min (≈Sun 08:37)
#     [ckpt] epoch 18 -> unet3d_ckpt_tx80_b40.pkl
#   ep 18/120  mse=0.03288  phys=0.02787  49.2s/ep  ·  101 epochs left  ·  ETA 82.7 min (≈Sun 08:37)
#   ep 19/120  mse=0.03221  phys=0.02832  49.3s/ep  ·  100 epochs left  ·  ETA 81.9 min (≈Sun 08:37)
#     [ckpt] epoch 20 -> unet3d_ckpt_tx80_b40.pkl
#   ep 20/120  mse=0.03250  phys=0.02831  49.2s/ep  ·  99 epochs left  ·  ETA 81.1 min (≈Sun 08:37)
#   ep 21/120  mse=0.03221  phys=0.02930  49.2s/ep  ·  98 epochs left  ·  ETA 80.3 min (≈Sun 08:37)
#     [ckpt] epoch 22 -> unet3d_ckpt_tx80_b40.pkl
#   ep 22/120  mse=0.03153  phys=0.02872  49.1s/ep  ·  97 epochs left  ·  ETA 79.5 min (≈Sun 08:37)
#   ep 23/120  mse=0.03151  phys=0.02853  49.1s/ep  ·  96 epochs left  ·  ETA 78.7 min (≈Sun 08:37)
#     [ckpt] epoch 24 -> unet3d_ckpt_tx80_b40.pkl
#   ep 24/120  mse=0.03134  phys=0.02901  49.2s/ep  ·  95 epochs left  ·  ETA 77.8 min (≈Sun 08:37)
#   ep 25/120  mse=0.03089  phys=0.03002  49.2s/ep  ·  94 epochs left  ·  ETA 77.0 min (≈Sun 08:37)
#     [ckpt] epoch 26 -> unet3d_ckpt_tx80_b40.pkl
#   ep 26/120  mse=0.03077  phys=0.02986  49.2s/ep  ·  93 epochs left  ·  ETA 76.2 min (≈Sun 08:37)
#   ep 27/120  mse=0.03079  phys=0.02931  49.1s/ep  ·  92 epochs left  ·  ETA 75.4 min (≈Sun 08:37)
#     [ckpt] epoch 28 -> unet3d_ckpt_tx80_b40.pkl
#   ep 28/120  mse=0.03072  phys=0.03054  49.2s/ep  ·  91 epochs left  ·  ETA 74.6 min (≈Sun 08:37)
#   ep 29/120  mse=0.03020  phys=0.03004  49.1s/ep  ·  90 epochs left  ·  ETA 73.7 min (≈Sun 08:37)
#     [ckpt] epoch 30 -> unet3d_ckpt_tx80_b40.pkl
#   ep 30/120  mse=0.02995  phys=0.03074  49.0s/ep  ·  89 epochs left  ·  ETA 72.9 min (≈Sun 08:37)
#   ep 31/120  mse=0.02995  phys=0.03030  49.1s/ep  ·  88 epochs left  ·  ETA 72.1 min (≈Sun 08:37)
#     [ckpt] epoch 32 -> unet3d_ckpt_tx80_b40.pkl
#   ep 32/120  mse=0.02978  phys=0.03102  49.2s/ep  ·  87 epochs left  ·  ETA 71.3 min (≈Sun 08:37)
#   ep 33/120  mse=0.02966  phys=0.03053  49.1s/ep  ·  86 epochs left  ·  ETA 70.5 min (≈Sun 08:37)
#     [ckpt] epoch 34 -> unet3d_ckpt_tx80_b40.pkl
#   ep 34/120  mse=0.02917  phys=0.03119  49.1s/ep  ·  85 epochs left  ·  ETA 69.6 min (≈Sun 08:37)
#   ep 35/120  mse=0.02893  phys=0.03223  49.0s/ep  ·  84 epochs left  ·  ETA 68.8 min (≈Sun 08:37)
#     [ckpt] epoch 36 -> unet3d_ckpt_tx80_b40.pkl
#   ep 36/120  mse=0.02891  phys=0.03149  49.1s/ep  ·  83 epochs left  ·  ETA 68.0 min (≈Sun 08:37)
#   ep 37/120  mse=0.02867  phys=0.03184  49.1s/ep  ·  82 epochs left  ·  ETA 67.2 min (≈Sun 08:37)
#     [ckpt] epoch 38 -> unet3d_ckpt_tx80_b40.pkl
#   ep 38/120  mse=0.02848  phys=0.03289  49.3s/ep  ·  81 epochs left  ·  ETA 66.4 min (≈Sun 08:37)
#   ep 39/120  mse=0.02815  phys=0.03362  49.2s/ep  ·  80 epochs left  ·  ETA 65.5 min (≈Sun 08:37)
#     [ckpt] epoch 40 -> unet3d_ckpt_tx80_b40.pkl
#   ep 40/120  mse=0.02816  phys=0.03318  49.1s/ep  ·  79 epochs left  ·  ETA 64.7 min (≈Sun 08:37)
#   ep 41/120  mse=0.02771  phys=0.03329  49.1s/ep  ·  78 epochs left  ·  ETA 63.9 min (≈Sun 08:37)
#     [ckpt] epoch 42 -> unet3d_ckpt_tx80_b40.pkl
#   ep 42/120  mse=0.02747  phys=0.03353  49.2s/ep  ·  77 epochs left  ·  ETA 63.1 min (≈Sun 08:37)
#   ep 43/120  mse=0.02740  phys=0.03422  49.1s/ep  ·  76 epochs left  ·  ETA 62.3 min (≈Sun 08:37)
#     [ckpt] epoch 44 -> unet3d_ckpt_tx80_b40.pkl
#   ep 44/120  mse=0.02712  phys=0.03561  49.1s/ep  ·  75 epochs left  ·  ETA 61.4 min (≈Sun 08:37)
#   ep 45/120  mse=0.02732  phys=0.03439  49.1s/ep  ·  74 epochs left  ·  ETA 60.6 min (≈Sun 08:37)
#     [ckpt] epoch 46 -> unet3d_ckpt_tx80_b40.pkl
#   ep 46/120  mse=0.02694  phys=0.03451  49.1s/ep  ·  73 epochs left  ·  ETA 59.8 min (≈Sun 08:37)
#   ep 47/120  mse=0.02680  phys=0.03492  48.8s/ep  ·  72 epochs left  ·  ETA 59.0 min (≈Sun 08:37)
#     [ckpt] epoch 48 -> unet3d_ckpt_tx80_b40.pkl
#   ep 48/120  mse=0.02622  phys=0.03578  48.9s/ep  ·  71 epochs left  ·  ETA 58.1 min (≈Sun 08:37)
#   ep 49/120  mse=0.02630  phys=0.03579  48.8s/ep  ·  70 epochs left  ·  ETA 57.3 min (≈Sun 08:37)
#     [ckpt] epoch 50 -> unet3d_ckpt_tx80_b40.pkl
#   ep 50/120  mse=0.02588  phys=0.03606  48.8s/ep  ·  69 epochs left  ·  ETA 56.5 min (≈Sun 08:37)
#   ep 51/120  mse=0.02602  phys=0.03686  49.0s/ep  ·  68 epochs left  ·  ETA 55.7 min (≈Sun 08:37)
#     [ckpt] epoch 52 -> unet3d_ckpt_tx80_b40.pkl
#   ep 52/120  mse=0.02558  phys=0.03655  48.8s/ep  ·  67 epochs left  ·  ETA 54.8 min (≈Sun 08:37)
#   ep 53/120  mse=0.02537  phys=0.03661  49.0s/ep  ·  66 epochs left  ·  ETA 54.0 min (≈Sun 08:37)
#     [ckpt] epoch 54 -> unet3d_ckpt_tx80_b40.pkl
#   ep 54/120  mse=0.02540  phys=0.03727  48.9s/ep  ·  65 epochs left  ·  ETA 53.2 min (≈Sun 08:37)
#   ep 55/120  mse=0.02546  phys=0.03694  48.8s/ep  ·  64 epochs left  ·  ETA 52.4 min (≈Sun 08:37)
#     [ckpt] epoch 56 -> unet3d_ckpt_tx80_b40.pkl
#   ep 56/120  mse=0.02452  phys=0.03853  48.8s/ep  ·  63 epochs left  ·  ETA 51.6 min (≈Sun 08:37)
#   ep 57/120  mse=0.02474  phys=0.03826  48.9s/ep  ·  62 epochs left  ·  ETA 50.7 min (≈Sun 08:37)
#     [ckpt] epoch 58 -> unet3d_ckpt_tx80_b40.pkl
#   ep 58/120  mse=0.02482  phys=0.03694  48.8s/ep  ·  61 epochs left  ·  ETA 49.9 min (≈Sun 08:37)
#   ep 59/120  mse=0.02415  phys=0.03870  48.9s/ep  ·  60 epochs left  ·  ETA 49.1 min (≈Sun 08:37)
#     [ckpt] epoch 60 -> unet3d_ckpt_tx80_b40.pkl
#   ep 60/120  mse=0.02414  phys=0.03850  48.8s/ep  ·  59 epochs left  ·  ETA 48.3 min (≈Sun 08:37)
#   ep 61/120  mse=0.02358  phys=0.03928  48.9s/ep  ·  58 epochs left  ·  ETA 47.4 min (≈Sun 08:37)
#     [ckpt] epoch 62 -> unet3d_ckpt_tx80_b40.pkl
#   ep 62/120  mse=0.02373  phys=0.03866  48.9s/ep  ·  57 epochs left  ·  ETA 46.6 min (≈Sun 08:37)
#   ep 63/120  mse=0.02377  phys=0.03906  48.9s/ep  ·  56 epochs left  ·  ETA 45.8 min (≈Sun 08:37)
#     [ckpt] epoch 64 -> unet3d_ckpt_tx80_b40.pkl
#   ep 64/120  mse=0.02323  phys=0.03974  48.8s/ep  ·  55 epochs left  ·  ETA 45.0 min (≈Sun 08:37)
#   ep 65/120  mse=0.02347  phys=0.03942  48.9s/ep  ·  54 epochs left  ·  ETA 44.2 min (≈Sun 08:37)
#     [ckpt] epoch 66 -> unet3d_ckpt_tx80_b40.pkl
#   ep 66/120  mse=0.02246  phys=0.04087  49.0s/ep  ·  53 epochs left  ·  ETA 43.3 min (≈Sun 08:37)
#   ep 67/120  mse=0.02232  phys=0.04113  48.8s/ep  ·  52 epochs left  ·  ETA 42.5 min (≈Sun 08:37)
#     [ckpt] epoch 68 -> unet3d_ckpt_tx80_b40.pkl
#   ep 68/120  mse=0.02275  phys=0.04051  49.0s/ep  ·  51 epochs left  ·  ETA 41.7 min (≈Sun 08:37)
#   ep 69/120  mse=0.02244  phys=0.04006  48.8s/ep  ·  50 epochs left  ·  ETA 40.9 min (≈Sun 08:37)
#     [ckpt] epoch 70 -> unet3d_ckpt_tx80_b40.pkl
#   ep 70/120  mse=0.02223  phys=0.04011  48.9s/ep  ·  49 epochs left  ·  ETA 40.1 min (≈Sun 08:37)
#   ep 71/120  mse=0.02160  phys=0.04064  49.0s/ep  ·  48 epochs left  ·  ETA 39.2 min (≈Sun 08:37)
#     [ckpt] epoch 72 -> unet3d_ckpt_tx80_b40.pkl
#   ep 72/120  mse=0.02200  phys=0.04038  48.9s/ep  ·  47 epochs left  ·  ETA 38.4 min (≈Sun 08:37)
#   ep 73/120  mse=0.02145  phys=0.04111  48.8s/ep  ·  46 epochs left  ·  ETA 37.6 min (≈Sun 08:37)
#     [ckpt] epoch 74 -> unet3d_ckpt_tx80_b40.pkl
#   ep 74/120  mse=0.02096  phys=0.04150  48.9s/ep  ·  45 epochs left  ·  ETA 36.8 min (≈Sun 08:37)
#   ep 75/120  mse=0.02085  phys=0.04166  48.9s/ep  ·  44 epochs left  ·  ETA 36.0 min (≈Sun 08:37)
#     [ckpt] epoch 76 -> unet3d_ckpt_tx80_b40.pkl
#   ep 76/120  mse=0.02067  phys=0.04152  49.0s/ep  ·  43 epochs left  ·  ETA 35.1 min (≈Sun 08:37)
#   ep 77/120  mse=0.02072  phys=0.04288  48.8s/ep  ·  42 epochs left  ·  ETA 34.3 min (≈Sun 08:37)
#     [ckpt] epoch 78 -> unet3d_ckpt_tx80_b40.pkl
#   ep 78/120  mse=0.02036  phys=0.04211  48.8s/ep  ·  41 epochs left  ·  ETA 33.5 min (≈Sun 08:37)
#   ep 79/120  mse=0.02032  phys=0.04284  49.0s/ep  ·  40 epochs left  ·  ETA 32.7 min (≈Sun 08:37)
#     [ckpt] epoch 80 -> unet3d_ckpt_tx80_b40.pkl
#   ep 80/120  mse=0.02005  phys=0.04274  48.9s/ep  ·  39 epochs left  ·  ETA 31.9 min (≈Sun 08:37)
#   ep 81/120  mse=0.02004  phys=0.04256  49.0s/ep  ·  38 epochs left  ·  ETA 31.1 min (≈Sun 08:37)
#     [ckpt] epoch 82 -> unet3d_ckpt_tx80_b40.pkl
#   ep 82/120  mse=0.02051  phys=0.04210  49.0s/ep  ·  37 epochs left  ·  ETA 30.2 min (≈Sun 08:37)
#   ep 83/120  mse=0.02000  phys=0.04246  49.0s/ep  ·  36 epochs left  ·  ETA 29.4 min (≈Sun 08:37)
#     [ckpt] epoch 84 -> unet3d_ckpt_tx80_b40.pkl
#   ep 84/120  mse=0.01933  phys=0.04375  48.9s/ep  ·  35 epochs left  ·  ETA 28.6 min (≈Sun 08:37)
#   ep 85/120  mse=0.01958  phys=0.04276  49.0s/ep  ·  34 epochs left  ·  ETA 27.8 min (≈Sun 08:37)
#     [ckpt] epoch 86 -> unet3d_ckpt_tx80_b40.pkl
#   ep 86/120  mse=0.01930  phys=0.04379  49.0s/ep  ·  33 epochs left  ·  ETA 27.0 min (≈Sun 08:37)
#   ep 87/120  mse=0.01855  phys=0.04375  49.1s/ep  ·  32 epochs left  ·  ETA 26.2 min (≈Sun 08:37)
#     [ckpt] epoch 88 -> unet3d_ckpt_tx80_b40.pkl
#   ep 88/120  mse=0.01848  phys=0.04481  49.0s/ep  ·  31 epochs left  ·  ETA 25.3 min (≈Sun 08:37)
#   ep 89/120  mse=0.01841  phys=0.04376  48.9s/ep  ·  30 epochs left  ·  ETA 24.5 min (≈Sun 08:37)
#     [ckpt] epoch 90 -> unet3d_ckpt_tx80_b40.pkl
#   ep 90/120  mse=0.01814  phys=0.04362  48.8s/ep  ·  29 epochs left  ·  ETA 23.7 min (≈Sun 08:37)
#   ep 91/120  mse=0.01818  phys=0.04415  48.8s/ep  ·  28 epochs left  ·  ETA 22.9 min (≈Sun 08:37)
#     [ckpt] epoch 92 -> unet3d_ckpt_tx80_b40.pkl
#   ep 92/120  mse=0.01812  phys=0.04366  48.9s/ep  ·  27 epochs left  ·  ETA 22.1 min (≈Sun 08:37)
#   ep 93/120  mse=0.01784  phys=0.04455  48.9s/ep  ·  26 epochs left  ·  ETA 21.2 min (≈Sun 08:37)
#     [ckpt] epoch 94 -> unet3d_ckpt_tx80_b40.pkl
#   ep 94/120  mse=0.01792  phys=0.04482  48.8s/ep  ·  25 epochs left  ·  ETA 20.4 min (≈Sun 08:37)
#   ep 95/120  mse=0.01931  phys=0.04241  48.8s/ep  ·  24 epochs left  ·  ETA 19.6 min (≈Sun 08:37)
#     [ckpt] epoch 96 -> unet3d_ckpt_tx80_b40.pkl
#   ep 96/120  mse=0.01813  phys=0.04479  48.9s/ep  ·  23 epochs left  ·  ETA 18.8 min (≈Sun 08:37)
#   ep 97/120  mse=0.01704  phys=0.04578  49.0s/ep  ·  22 epochs left  ·  ETA 18.0 min (≈Sun 08:37)
#     [ckpt] epoch 98 -> unet3d_ckpt_tx80_b40.pkl
#   ep 98/120  mse=0.01705  phys=0.04525  49.0s/ep  ·  21 epochs left  ·  ETA 17.2 min (≈Sun 08:37)
#   ep 99/120  mse=0.01656  phys=0.04571  49.1s/ep  ·  20 epochs left  ·  ETA 16.3 min (≈Sun 08:37)
#     [ckpt] epoch 100 -> unet3d_ckpt_tx80_b40.pkl
#   ep100/120  mse=0.01763  phys=0.04383  48.9s/ep  ·  19 epochs left  ·  ETA 15.5 min (≈Sun 08:37)
#   ep101/120  mse=0.01735  phys=0.04454  48.9s/ep  ·  18 epochs left  ·  ETA 14.7 min (≈Sun 08:37)
#     [ckpt] epoch 102 -> unet3d_ckpt_tx80_b40.pkl
#   ep102/120  mse=0.01611  phys=0.04512  48.8s/ep  ·  17 epochs left  ·  ETA 13.9 min (≈Sun 08:37)
#   ep103/120  mse=0.01633  phys=0.04489  48.8s/ep  ·  16 epochs left  ·  ETA 13.1 min (≈Sun 08:37)
#     [ckpt] epoch 104 -> unet3d_ckpt_tx80_b40.pkl
#   ep104/120  mse=0.01617  phys=0.04521  48.9s/ep  ·  15 epochs left  ·  ETA 12.3 min (≈Sun 08:37)
#   ep105/120  mse=0.01622  phys=0.04481  48.9s/ep  ·  14 epochs left  ·  ETA 11.4 min (≈Sun 08:37)
#     [ckpt] epoch 106 -> unet3d_ckpt_tx80_b40.pkl
#   ep106/120  mse=0.01568  phys=0.04492  48.8s/ep  ·  13 epochs left  ·  ETA 10.6 min (≈Sun 08:37)
#   ep107/120  mse=0.01633  phys=0.04557  48.9s/ep  ·  12 epochs left  ·  ETA 9.8 min (≈Sun 08:37)
#     [ckpt] epoch 108 -> unet3d_ckpt_tx80_b40.pkl
#   ep108/120  mse=0.01547  phys=0.04616  49.0s/ep  ·  11 epochs left  ·  ETA 9.0 min (≈Sun 08:37)
#   ep109/120  mse=0.01517  phys=0.04632  49.0s/ep  ·  10 epochs left  ·  ETA 8.2 min (≈Sun 08:37)
#     [ckpt] epoch 110 -> unet3d_ckpt_tx80_b40.pkl
#   ep110/120  mse=0.01542  phys=0.04566  49.0s/ep  ·  9 epochs left  ·  ETA 7.4 min (≈Sun 08:37)
#   ep111/120  mse=0.01531  phys=0.04572  48.9s/ep  ·  8 epochs left  ·  ETA 6.5 min (≈Sun 08:37)
#     [ckpt] epoch 112 -> unet3d_ckpt_tx80_b40.pkl
#   ep112/120  mse=0.01495  phys=0.04584  49.0s/ep  ·  7 epochs left  ·  ETA 5.7 min (≈Sun 08:37)
#   ep113/120  mse=0.01577  phys=0.04524  48.8s/ep  ·  6 epochs left  ·  ETA 4.9 min (≈Sun 08:37)
#     [ckpt] epoch 114 -> unet3d_ckpt_tx80_b40.pkl
#   ep114/120  mse=0.01578  phys=0.04577  48.9s/ep  ·  5 epochs left  ·  ETA 4.1 min (≈Sun 08:37)
#   ep115/120  mse=0.01510  phys=0.04588  48.8s/ep  ·  4 epochs left  ·  ETA 3.3 min (≈Sun 08:37)
#     [ckpt] epoch 116 -> unet3d_ckpt_tx80_b40.pkl
#   ep116/120  mse=0.01449  phys=0.04582  49.2s/ep  ·  3 epochs left  ·  ETA 2.4 min (≈Sun 08:37)
#   ep117/120  mse=0.01457  phys=0.04688  49.0s/ep  ·  2 epochs left  ·  ETA 1.6 min (≈Sun 08:37)
#     [ckpt] epoch 118 -> unet3d_ckpt_tx80_b40.pkl
#   ep118/120  mse=0.01389  phys=0.04667  49.0s/ep  ·  1 epochs left  ·  ETA 49s (≈Sun 08:37)
#   ep119/120  mse=0.01468  phys=0.04622  48.9s/ep  ·  0 epochs left  ·  ETA 0s (≈Sun 08:37)
#     [ckpt] epoch 120 -> unet3d_ckpt_tx80_b40.pkl
# saved /content/drive/MyDrive/simv2_multiband/unet3d_tx80_b40.npz  (ckpt /content/drive/MyDrive/simv2_multiband/unet3d_ckpt_tx80_b40.pkl kept for resume)
# weights -> /content/drive/MyDrive/simv2_multiband/unet3d_tx80_b40.npz

# %% [markdown]
# ## 5 · Phase D — validate vs a fresh FDTD (optional)

# %%
# Phase D — TEST the trained surrogate on HELD-OUT data (fresh transmitters it never saw)
# vs a fresh FDTD ground truth. Prints envelope-dB RMSE / Spearman / coherence + a pred-vs-truth
# slice. Uses the same mesh-bake pipeline as training. Run after Phase C finishes.
r = T.validate_conformal(str(WEIGHTS), "LTE_B71_617", n_tx=3, boxes_per=48,
                         out_png=str(PERSIST / "phaseD_617.png"))
from IPython.display import Image
Image(str(PERSIST / "phaseD_617.png"))
# Out:
# model: cin=18 base=48  ·  device=gpu
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
#   two-tier: 5% of faces = sub-wavelength clutter (<20 verts) → homogenized
# Phase D · LTE_B71_617 · 144 held-out boxes (seed 999)
#    MSE=0.02894   envelope dB RMSE=10.45 dB   Spearman=+0.362   coherence=0.671
#    wrote /content/drive/MyDrive/simv2_multiband/phaseD_617.png

# %% [markdown]
# ## Resuming after a timeout / out of credits
# **Progress lives on Google Drive, not GitHub** — you never push anything to GitHub between sessions.
# GitHub only holds the code (cloned fresh each session); shards + the checkpoint sit in your Drive folder
# and persist no matter how the runtime ends (timeout, out of credits, or you interrupt).
# 1. New session → re-select the **A100** runtime.
# 2. **Runtime → Run all.** Cells 0–2 re-mount Drive + re-clone the code + decompress the OBJ (seconds).
# 3. Phase B prints `[skip]` for every shard already on Drive — it only generates the missing transmitters
#    (per-Tx resume; a kill costs at most the one Tx in flight).
# 4. Phase C prints `[resume] @ epoch N` and continues from the last checkpoint (loses ≤ `CKPT_EVERY` epochs).
#
# ## Knobs
# - **Faster / cheaper**: `EPOCHS` 60–80, `BOXES_PER` 150, or `N_TX` 15. Still resumable.
# - **No OBJ on Drive**: `MESH_BAKE=False` → frozen-geometry path (εr/σ upsampled from 0.3 m, coarser but
#   needs no OBJ and no CuPy).
# - **High-band memory** (3700/5500 MHz) is the tightest spot; `D.BAND_PLAN` already shrinks their region.
# - **Export to ONNX**: copy the trained JAX weights into the PyTorch `UNet3DField(cin=18, base=48)` →
#   `torch.onnx.export` (parity proven in `unet3d_jax.py`).
